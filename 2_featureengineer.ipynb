# %%
import pandas as pd

# %%
data_cleaned = pd.read_csv("post_processed_data_cleaned.csv")
data_cleaned.head()
# Out:
#       video_id         video_published_at video_trending__date  \
# 0  bB3-CUMERIU  2024-10-11 00:00:06+00:00           2024-10-12
# 1  zfb0whgBBA8  2024-10-11 11:07:25+00:00           2024-10-12
# 2  UVb6QOKy0bI  2024-10-09 12:30:27+00:00           2024-10-12
# 3  IINqHUM71Xo  2024-10-12 02:03:10+00:00           2024-10-12
# 4  6YMY62tMLUA  2024-10-09 09:00:08+00:00           2024-10-12
#
#   video_trending_country                channel_id  \
# 0   United Arab Emirates  UCNYi_zGmR519r5gYdOKLTjQ
# 1   United Arab Emirates  UCgGYPnVJytkr6sVNLQ-l0zQ
# 2   United Arab Emirates  UCOzubmwpVZI7gD0Jf7Bk3Aw
# 3   United Arab Emirates  UCHZArBtk2eda0AVR6HI4qMw
# 4   United Arab Emirates  UCq-Fj5jknLsUf-MWSy4_brA
#
#                                          video_title  \
# 0             JENNIE - Mantra (Official Music Video)
# 1            تحدي الحقيبة مع ابو عبير 🔥 | سلسلتنا #2
# 2  Bougainvillea Trailer | October 17 | Jyothirma...
# 3                        الفيديو التشويقي لـ Regalia
# 4  Bhool Bhulaiyaa 3 (Official Trailer): Kartik A...
#
#                                    video_description  \
# 0  Official music video for “Mantra” by JENNIE ou...
# 1  1,375,547 مشترك❤️\n\nـــــــــــــــــــــــــ...
# 2  Presenting The Official Trailer of Bougainvill...
# 3  هل انت جاهز للتحدي الجديد Regalia كل شيء يتعلق...
# 4  Haveli Ka Darwaza Khula Ek baar Phir… Rooh Bab...
#
#                           video_default_thumbnail video_category_id  \
# 0  https://i.ytimg.com/vi/bB3-CUMERIU/default.jpg             Music
# 1  https://i.ytimg.com/vi/zfb0whgBBA8/default.jpg            Gaming
# 2  https://i.ytimg.com/vi/UVb6QOKy0bI/default.jpg  Film & Animation
# 3  https://i.ytimg.com/vi/IINqHUM71Xo/default.jpg            Gaming
# 4  https://i.ytimg.com/vi/6YMY62tMLUA/default.jpg             Music
#
#                                           video_tags  ...  \
# 0  JENNIE,Mantra,제니,Jennie Mantra,Jennie from Bla...  ...
# 1  تشكيله,فيفا,فيفا20,التمت,درافت,زلاتان,ام,جي,مل...  ...
# 2                                                NaN  ...
# 3  #FreeFire #FreeFireMax,جواهر_مجانية #,فري_فاير...  ...
# 4  tseries,tseries songs,bhool bhulaiyaa 3,bhool ...  ...
#
#                                  channel_description  \
# 0                           No description available
# 1             صانع محتوى وانزل مقاطع بشكل غير منظم 🌚
# 2  Official YouTube Channel Of Amal Neerad Produc...
# 3  Official YouTube account for Garena Free Fire ...
# 4  "Music can change the world". T-Series is Indi...
#
#            channel_custom_url              channel_published_at  \
# 0             @jennierubyjane  2021-01-13 06:19:55.866890+00:00
# 1                    @mrlle99         2012-08-01 16:24:26+00:00
# 2  @amalneeradproductions5264         2017-05-31 14:31:01+00:00
# 3         @garenafreefiremena         2019-05-15 09:25:26+00:00
# 4                    @tseries         2006-03-13 14:27:05+00:00
#
#    channel_country  channel_view_count  channel_subscriber_count  \
# 0          Unknown           464615150                  11600000
# 1     Saudi Arabia           114331110                   1380000
# 2          Unknown            19991522                     40600
# 3          Morocco           655373060                   4710000
# 4            India        269373477007                 276000000
#
#    channel_have_hidden_subscribers channel_video_count  \
# 0                            False                  43
# 1                            False                 314
# 2                            False                  56
# 3                            False                1746
# 4                            False               21864
#
#                             channel_localized_title  \
# 0                                            JENNIE
# 1                                      LLE عبدالاله
# 2                           Amal Neerad Productions
# 3  Garena Free Fire Middle East and Africa - Arabic
# 4                                          T-Series
#
#                        channel_localized_description
# 0                 No localized description available
# 1             صانع محتوى وانزل مقاطع بشكل غير منظم 🌚
# 2  Official YouTube Channel Of Amal Neerad Produc...
# 3  Official YouTube account for Garena Free Fire ...
# 4  "Music can change the world". T-Series is Indi...
#
# [5 rows x 28 columns]

# %%
data_cleaned['video_view_count'].replace(0, pd.NA, inplace=True)
data_cleaned.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_5928\3210249691.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_cleaned['video_view_count'].replace(0, pd.NA, inplace=True)
#       video_id         video_published_at video_trending__date  \
# 0  bB3-CUMERIU  2024-10-11 00:00:06+00:00           2024-10-12
# 1  zfb0whgBBA8  2024-10-11 11:07:25+00:00           2024-10-12
# 2  UVb6QOKy0bI  2024-10-09 12:30:27+00:00           2024-10-12
# 3  IINqHUM71Xo  2024-10-12 02:03:10+00:00           2024-10-12
# 4  6YMY62tMLUA  2024-10-09 09:00:08+00:00           2024-10-12
#
#   video_trending_country                channel_id  \
# 0   United Arab Emirates  UCNYi_zGmR519r5gYdOKLTjQ
# 1   United Arab Emirates  UCgGYPnVJytkr6sVNLQ-l0zQ
# 2   United Arab Emirates  UCOzubmwpVZI7gD0Jf7Bk3Aw
# 3   United Arab Emirates  UCHZArBtk2eda0AVR6HI4qMw
# 4   United Arab Emirates  UCq-Fj5jknLsUf-MWSy4_brA
#
#                                          video_title  \
# 0             JENNIE - Mantra (Official Music Video)
# 1            تحدي الحقيبة مع ابو عبير 🔥 | سلسلتنا #2
# 2  Bougainvillea Trailer | October 17 | Jyothirma...
# 3                        الفيديو التشويقي لـ Regalia
# 4  Bhool Bhulaiyaa 3 (Official Trailer): Kartik A...
#
#                                    video_description  \
# 0  Official music video for “Mantra” by JENNIE ou...
# 1  1,375,547 مشترك❤️\n\nـــــــــــــــــــــــــ...
# 2  Presenting The Official Trailer of Bougainvill...
# 3  هل انت جاهز للتحدي الجديد Regalia كل شيء يتعلق...
# 4  Haveli Ka Darwaza Khula Ek baar Phir… Rooh Bab...
#
#                           video_default_thumbnail video_category_id  \
# 0  https://i.ytimg.com/vi/bB3-CUMERIU/default.jpg             Music
# 1  https://i.ytimg.com/vi/zfb0whgBBA8/default.jpg            Gaming
# 2  https://i.ytimg.com/vi/UVb6QOKy0bI/default.jpg  Film & Animation
# 3  https://i.ytimg.com/vi/IINqHUM71Xo/default.jpg            Gaming
# 4  https://i.ytimg.com/vi/6YMY62tMLUA/default.jpg             Music
#
#                                           video_tags  ...  \
# 0  JENNIE,Mantra,제니,Jennie Mantra,Jennie from Bla...  ...
# 1  تشكيله,فيفا,فيفا20,التمت,درافت,زلاتان,ام,جي,مل...  ...
# 2                                                NaN  ...
# 3  #FreeFire #FreeFireMax,جواهر_مجانية #,فري_فاير...  ...
# 4  tseries,tseries songs,bhool bhulaiyaa 3,bhool ...  ...
#
#                                  channel_description  \
# 0                           No description available
# 1             صانع محتوى وانزل مقاطع بشكل غير منظم 🌚
# 2  Official YouTube Channel Of Amal Neerad Produc...
# 3  Official YouTube account for Garena Free Fire ...
# 4  "Music can change the world". T-Series is Indi...
#
#            channel_custom_url              channel_published_at  \
# 0             @jennierubyjane  2021-01-13 06:19:55.866890+00:00
# 1                    @mrlle99         2012-08-01 16:24:26+00:00
# 2  @amalneeradproductions5264         2017-05-31 14:31:01+00:00
# 3         @garenafreefiremena         2019-05-15 09:25:26+00:00
# 4                    @tseries         2006-03-13 14:27:05+00:00
#
#    channel_country  channel_view_count  channel_subscriber_count  \
# 0          Unknown           464615150                  11600000
# 1     Saudi Arabia           114331110                   1380000
# 2          Unknown            19991522                     40600
# 3          Morocco           655373060                   4710000
# 4            India        269373477007                 276000000
#
#    channel_have_hidden_subscribers channel_video_count  \
# 0                            False                  43
# 1                            False                 314
# 2                            False                  56
# 3                            False                1746
# 4                            False               21864
#
#                             channel_localized_title  \
# 0                                            JENNIE
# 1                                      LLE عبدالاله
# 2                           Amal Neerad Productions
# 3  Garena Free Fire Middle East and Africa - Arabic
# 4                                          T-Series
#
#                        channel_localized_description
# 0                 No localized description available
# 1             صانع محتوى وانزل مقاطع بشكل غير منظم 🌚
# 2  Official YouTube Channel Of Amal Neerad Produc...
# 3  Official YouTube account for Garena Free Fire ...
# 4  "Music can change the world". T-Series is Indi...
#
# [5 rows x 28 columns]

# %%
data_cleaned['engagement_rate'] = (
    (data_cleaned['video_like_count'] + data_cleaned['video_comment_count']) /
    data_cleaned['video_view_count']
)
data_cleaned['engagement_rate'].head()
# Out:
# 0    0.106899
# 1    0.130919
# 2    0.040684
# 3    0.034280
# 4    0.019689
# Name: engagement_rate, dtype: float64

# %%
import pandas as pd

data_cleaned['video_trending__date'] = pd.to_datetime(data_cleaned['video_trending__date'])

data_cleaned['video_published_at'] = pd.to_datetime(data_cleaned['video_published_at'])

data_cleaned['video_published_at'] = data_cleaned['video_published_at'].dt.tz_localize(None)
data_cleaned['time_difference'] = data_cleaned['video_trending__date'] - data_cleaned['video_published_at']
data_cleaned[['video_trending__date', 'video_published_at', 'time_difference']]
# Out:
#        video_trending__date  video_published_at   time_difference
# 0                2024-10-12 2024-10-11 00:00:06   0 days 23:59:54
# 1                2024-10-12 2024-10-11 11:07:25   0 days 12:52:35
# 2                2024-10-12 2024-10-09 12:30:27   2 days 11:29:33
# 3                2024-10-12 2024-10-12 02:03:10 -1 days +21:56:50
# 4                2024-10-12 2024-10-09 09:00:08   2 days 14:59:52
# ...                     ...                 ...               ...
# 650043           2024-11-26 2024-11-20 00:30:35   5 days 23:29:25
# 650044           2024-11-26 2024-11-20 13:01:11   5 days 10:58:49
# 650045           2024-11-26 2024-11-19 17:00:02   6 days 06:59:58
# 650046           2024-11-26 2024-11-19 19:32:45   6 days 04:27:15
# 650047           2024-11-26 2024-11-18 22:01:44   7 days 01:58:16
#
# [650048 rows x 3 columns]

# %%
data_cleaned['video_duration']
# Out:
# 0            PT2M28S
# 1           PT43M24S
# 2            PT2M12S
# 3              PT15S
# 4            PT3M51S
#              ...
# 650043    PT5H38M38S
# 650044       PT11M3S
# 650045       PT2M10S
# 650046       PT2M52S
# 650047      PT59M52S
# Name: video_duration, Length: 650048, dtype: object

# %%
import pandas as pd
import isodate

data_cleaned['video_duration_seconds'] = data_cleaned['video_duration'].apply(lambda x: isodate.parse_duration(x).total_seconds())

# %%
feature_table_fixed = data_cleaned[['engagement_rate', 'time_difference', 'video_duration_seconds']].head()
feature_table_fixed
# Out:
#    engagement_rate   time_difference  video_duration_seconds
# 0         0.106899   0 days 23:59:54                   148.0
# 1         0.130919   0 days 12:52:35                  2604.0
# 2         0.040684   2 days 11:29:33                   132.0
# 3         0.034280 -1 days +21:56:50                    15.0
# 4         0.019689   2 days 14:59:52                   231.0

# %%
data_cleaned.head()
# Out:
#       video_id  video_published_at video_trending__date  \
# 0  bB3-CUMERIU 2024-10-11 00:00:06           2024-10-12
# 1  zfb0whgBBA8 2024-10-11 11:07:25           2024-10-12
# 2  UVb6QOKy0bI 2024-10-09 12:30:27           2024-10-12
# 3  IINqHUM71Xo 2024-10-12 02:03:10           2024-10-12
# 4  6YMY62tMLUA 2024-10-09 09:00:08           2024-10-12
#
#   video_trending_country                channel_id  \
# 0   United Arab Emirates  UCNYi_zGmR519r5gYdOKLTjQ
# 1   United Arab Emirates  UCgGYPnVJytkr6sVNLQ-l0zQ
# 2   United Arab Emirates  UCOzubmwpVZI7gD0Jf7Bk3Aw
# 3   United Arab Emirates  UCHZArBtk2eda0AVR6HI4qMw
# 4   United Arab Emirates  UCq-Fj5jknLsUf-MWSy4_brA
#
#                                          video_title  \
# 0             JENNIE - Mantra (Official Music Video)
# 1            تحدي الحقيبة مع ابو عبير 🔥 | سلسلتنا #2
# 2  Bougainvillea Trailer | October 17 | Jyothirma...
# 3                        الفيديو التشويقي لـ Regalia
# 4  Bhool Bhulaiyaa 3 (Official Trailer): Kartik A...
#
#                                    video_description  \
# 0  Official music video for “Mantra” by JENNIE ou...
# 1  1,375,547 مشترك❤️\n\nـــــــــــــــــــــــــ...
# 2  Presenting The Official Trailer of Bougainvill...
# 3  هل انت جاهز للتحدي الجديد Regalia كل شيء يتعلق...
# 4  Haveli Ka Darwaza Khula Ek baar Phir… Rooh Bab...
#
#                           video_default_thumbnail video_category_id  \
# 0  https://i.ytimg.com/vi/bB3-CUMERIU/default.jpg             Music
# 1  https://i.ytimg.com/vi/zfb0whgBBA8/default.jpg            Gaming
# 2  https://i.ytimg.com/vi/UVb6QOKy0bI/default.jpg  Film & Animation
# 3  https://i.ytimg.com/vi/IINqHUM71Xo/default.jpg            Gaming
# 4  https://i.ytimg.com/vi/6YMY62tMLUA/default.jpg             Music
#
#                                           video_tags  ... channel_country  \
# 0  JENNIE,Mantra,제니,Jennie Mantra,Jennie from Bla...  ...         Unknown
# 1  تشكيله,فيفا,فيفا20,التمت,درافت,زلاتان,ام,جي,مل...  ...    Saudi Arabia
# 2                                                NaN  ...         Unknown
# 3  #FreeFire #FreeFireMax,جواهر_مجانية #,فري_فاير...  ...         Morocco
# 4  tseries,tseries songs,bhool bhulaiyaa 3,bhool ...  ...           India
#
#   channel_view_count channel_subscriber_count  \
# 0          464615150                 11600000
# 1          114331110                  1380000
# 2           19991522                    40600
# 3          655373060                  4710000
# 4       269373477007                276000000
#
#    channel_have_hidden_subscribers  channel_video_count  \
# 0                            False                   43
# 1                            False                  314
# 2                            False                   56
# 3                            False                 1746
# 4                            False                21864
#
#                             channel_localized_title  \
# 0                                            JENNIE
# 1                                      LLE عبدالاله
# 2                           Amal Neerad Productions
# 3  Garena Free Fire Middle East and Africa - Arabic
# 4                                          T-Series
#
#                        channel_localized_description engagement_rate  \
# 0                 No localized description available        0.106899
# 1             صانع محتوى وانزل مقاطع بشكل غير منظم 🌚        0.130919
# 2  Official YouTube Channel Of Amal Neerad Produc...        0.040684
# 3  Official YouTube account for Garena Free Fire ...        0.034280
# 4  "Music can change the world". T-Series is Indi...        0.019689
#
#     time_difference video_duration_seconds
# 0   0 days 23:59:54                  148.0
# 1   0 days 12:52:35                 2604.0
# 2   2 days 11:29:33                  132.0
# 3 -1 days +21:56:50                   15.0
# 4   2 days 14:59:52                  231.0
#
# [5 rows x 31 columns]

# %%
data_cleaned.to_csv("data_cleaned_feature_31.csv", index=False) # done
